# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\railway.csv")
df
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31653 entries, 0 to 31652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Transaction ID       31653 non-null  object
#  1   Date of Purchase     31653 non-null  object
#  2   Time of Purchase     31653 non-null  object
#  3   Purchase Type        31653 non-null  object
#  4   Payment Method       31653 non-null  object
#  5   Railcard             10735 non-null  object
#  6   Ticket Class         31653 non-null  object
#  7   Ticket Type          31653 non-null  object
#  8   Price                31653 non-null  int64
#  9   Departure Station    31653 non-null  object
#  10  Arrival Destination  31653 non-null  object
#  11  Date of Journey      31653 non-null  object
#  12  Departure Time       31653 non-null  object
#  13  Arrival Time         31653 non-null  object
#  14  Actual Arrival Time  29773 non-null  object
# ...

# %%
df.drop_duplicates()
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date of Purchase', 'Time of Purchase',
#        'Purchase Type', 'Payment Method', 'Railcard', 'Ticket Class',
#        'Ticket Type', 'Price', 'Departure Station', 'Arrival Destination',
#        'Date of Journey', 'Departure Time', 'Arrival Time',
#        'Actual Arrival Time', 'Journey Status', 'Reason for Delay',
#        'Refund Request'],
#       dtype='object')

# %%
df['Railcard'].isnull
# Out:
# <bound method Series.isnull of 0        Adult
# 1        Adult
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 31648      NaN
# 31649      NaN
# 31650      NaN
# 31651      NaN
# 31652    Adult
# Name: Railcard, Length: 31653, dtype: object>

# %%
df['Reason for Delay'].isnull
# Out:
# <bound method Series.isnull of 0                   NaN
# 1        Signal Failure
# 2                   NaN
# 3                   NaN
# 4                   NaN
#               ...
# 31648               NaN
# 31649               NaN
# 31650               NaN
# 31651               NaN
# 31652               NaN
# Name: Reason for Delay, Length: 31653, dtype: object>

# %%
df['Actual Arrival Time'].isnull
# Out:
# <bound method Series.isnull of 0        13:30:00
# 1        11:40:00
# 2        18:45:00
# 3        22:30:00
# 4        19:00:00
#            ...
# 31648    20:30:00
# 31649    21:35:00
# 31650    20:45:00
# 31651    22:35:00
# 31652    22:00:00
# Name: Actual Arrival Time, Length: 31653, dtype: object>

# %%
df['Railcard'] =  df["Railcard"].fillna('None')

# %%
df['Reason for Delay'] = df["Reason for Delay"].fillna('No delay')

# %%
df
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...

# %%
df['Journey Status'].value_counts()
# Out:
# Journey Status
# On Time      27481
# Delayed       2292
# Cancelled     1880
# Name: count, dtype: int64

# %%
df['Actual Arrival Time'] = df["Actual Arrival Time"].fillna('Cancelled')

# %%
df
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...

# %%
df.dtypes
# Out:
# Transaction ID         object
# Date of Purchase       object
# Time of Purchase       object
# Purchase Type          object
# Payment Method         object
# Railcard               object
# Ticket Class           object
# Ticket Type            object
# Price                   int64
# Departure Station      object
# Arrival Destination    object
# Date of Journey        object
# Departure Time         object
# Arrival Time           object
# Actual Arrival Time    object
# Journey Status         object
# Reason for Delay       object
# Refund Request         object
# dtype: object

# %%
df
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...

# %%
df.head(50)
# Out:
#              Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0   da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1   b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2   f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3   b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4   2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
# 5   4e1dcd88-3d95-44ef-99fa       2023-12-30         07:56:06        Online
# 6   1c74479d-85a4-4ba1-a607       2023-12-31         00:02:01       Station
# 7   febf8dab-f808-46fa-bf2b       2023-12-31         01:35:18       Station
# 8   01df916f-4291-41ec-a37d       2023-12-31         01:43:09       Station
# 9   a8cedba7-1923-459d-b046       2023-12-31         03:05:52        Online
# 10  b3e5ca7d-e76c-49f2-b49f       2023-12-31         03:26:37        Online
# ...

# %%
df.to_excel("my_project_data.xlsx", index=False)

# %%
from IPython.display import FileLink

# %%
FileLink("my_project_data.xlsx")
# Out:
# C:\Users\DELL\DEPI Final Project\my_project_data.xlsx
